# %%
import os
import pandas as pd
import numpy as np
import pickle

import yaml

cfg = None
    #' load config.yaml file in the root dir 
with open("../config.yaml", 'r') as ymlfile:
    cfg = yaml.load(ymlfile, Loader=yaml.FullLoader)
    
# Use 3 decimal places in output display
pd.set_option("display.precision", 3)

# Don't wrap repr(DataFrame) across additional lines
pd.set_option("display.expand_frame_repr", False)

# Set max rows displayed in output to 25
pd.set_option("display.max_rows", 25)

pd.set_option('display.float_format', lambda x: '%.2f' % x)


#Function to get data frame summary
def get_data_frame_summmary(data_frame, sort_by='percent_missing', ascending=False):
    unique_values = data_frame.apply(lambda x: [x.unique()])
    unique_counts = data_frame.apply(lambda x: len(x.unique()))
    percent_missing = data_frame.apply(lambda x: sum(pd.isnull(x))/len(x)*100)
    data_type = data_frame.dtypes

    return pd.DataFrame(dict(unique_values = unique_values, 
                                unique_counts = unique_counts,
                                data_type = data_type,
                                percent_missing = percent_missing,
                                )).reset_index().sort_values(by=sort_by, ascending=ascending)

# Function to drop outliers of numeric columns
def drop_outliers(data_frame, exclude=[]):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    num_cols = data_frame.select_dtypes(include=numerics).columns

    num_cols = num_cols.difference(exclude)
    
    for colname in num_cols:
        upper_lim = data_frame[colname].quantile(.95)
        lower_lim = data_frame[colname].quantile(.05)
        
        print(f'Dropping outliers for {colname} upper limit = {upper_lim} and lower limit = {lower_lim}')
        data_frame = data_frame[(data_frame[colname] < upper_lim) & (data_frame[colname] > lower_lim)]
      
    return data_frame


# Function to drop outliers of numeric columns
def scale_numeric_features(data_frame, exclude=[], 
                           method='standardize',
                           inplace=False):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    num_cols = data_frame.select_dtypes(include=numerics).columns

    num_cols = num_cols.difference(exclude)
    print(f'********************* - Scaling following {len(num_cols)} features - **********************')
    for colname in num_cols:
        new_colname = colname if inplace else colname+'_'+method+'d'
        print(f' {colname} {method}d to {new_colname}')
        
        if method == 'standardize':              
              data_frame[new_colname] = (data_frame[colname] - data_frame[colname].mean()) / data_frame[colname].std()
        elif method == 'normalize':
              data_frame[new_colname] = (data_frame[colname] - data_frame[colname].min()) / (data_frame[colname].max() - data_frame[colname].min())
        else:
              print(f'Unknown method {method} specified, please select one of "standardize" or "normalize"')

      
    return data_frame


def remove_items(iteamlist, removelist):
    return [ele for ele in iteamlist if ele not in removelist]

def diff(first, second):
    second = set(second)
    return [item for item in first if item not in second]
    
def months_between_columns(date_series1, date_series2):
    return round((date_series1-date_series2) / np.timedelta64(1, 'M'))

# %%
# Read Data
churn_activities = pd.read_pickle('../data/pickle/191212_churn_activities.pickle')

df = churn_activities
del churn_activities

df.head()
# Out:
#                           Opportunity      Created By       Account ID                                  Company / Account     Contact Lead Priority Activity Type  Task Task/Event Record Type  ...        Assigned              Date Product Name               Assigned Role Assigned Role Display      Created Date             Start               End        ECR Id Parent ECR-ID
# 0                                 NaN  Chinami Takebe  0010Y00001FvC5o  National Hospital Organization Hokkaido Medica...  ???? Amano  NaN      NaN  Face to Face     0                  Event  ...  Chinami Takebe  2019-07-04T00:00          NaN                HS-APAC-JP_N                   NaN  2019-07-04T00:00  2019-07-04T02:00  2019-07-04T02:30    ECR-593174    ECR-593174
# 1  SY_ELS_CK_2020_Mito Medical Center    Shiho Yakabe  0010Y00001FwK3c                                Mito Medical Center       ?? ??  NaN      NaN           NaN     0                  Event  ...    Shiho Yakabe  2019-11-15T00:00          NaN                HS-APAC-JP_C                   NaN  2019-12-04T00:00  2019-11-15T03:00  2019-11-15T04:00    ECR-202329  ECR-10122302
# 2                                 NaN       David Lee  0010Y00001D1OCN                                  Yonsei University   ???? ????  NaN      NaN       Virtual     0                  Event  ...       David Lee  2019-04-26T00:00          NaN  A&G-APAC-KOREA-TAIWAN-CORE                   NaN  2019-04-29T00:00  2019-04-26T01:00  2019-04-26T02:00    ECR-137560    ECR-137560
# 3                     DL_BF 19_Yonsei       David Lee  0010Y00001D1OCN                                  Yonsei University   ???? ????  NaN      NaN  Face to Face     0                  Event  ...       David Lee  2019-04-17T00:00          NaN  A&G-APAC-KOREA-TAIWAN-CORE                   NaN  2019-04-22T00:00  2019-04-17T06:00  2019-04-17T07:00    ECR-137560    ECR-137560
# 4                                 NaN       Grace Kim  0013z00002LttHV                               Daejeon Sun Hospital         ???  NaN      NaN  Face to Face     0                  Event  ...       Grace Kim  2019-09-26T00:00          NaN               RM-HS-APAC-KR                   NaN  2019-09-29T00:00  2019-09-26T02:30  2019-09-26T06:00  ECR-10325865  ECR-10325865
#
# [5 rows x 31 columns]

# %% [markdown]
# # Replace strings indicating missing data with null

# %%
#replace strings indicating missing data with null
df.replace(['nan', 'N.A', 'N.A.', 'NaN', 'Nan', '00-00-00', '0-00-00', 'Unknown'], np.nan, inplace=True)
df.replace('.*\?.*', np.nan, regex=True, inplace=True)
df
# Out:
#                                Opportunity              Created By       Account ID                                  Company / Account Contact Lead  Priority Activity Type  Task Task/Event Record Type  ...                Assigned              Date Product Name               Assigned Role Assigned Role Display      Created Date             Start               End        ECR Id Parent ECR-ID
# 0                                      NaN          Chinami Takebe  0010Y00001FvC5o  National Hospital Organization Hokkaido Medica...     NaN  NaN       NaN  Face to Face     0                  Event  ...          Chinami Takebe  2019-07-04T00:00          NaN                HS-APAC-JP_N                   NaN  2019-07-04T00:00  2019-07-04T02:00  2019-07-04T02:30    ECR-593174    ECR-593174
# 1       SY_ELS_CK_2020_Mito Medical Center            Shiho Yakabe  0010Y00001FwK3c                                Mito Medical Center     NaN  NaN       NaN           NaN     0                  Event  ...            Shiho Yakabe  2019-11-15T00:00          NaN                HS-APAC-JP_C                   NaN  2019-12-04T00:00  2019-11-15T03:00  2019-11-15T04:00    ECR-202329  ECR-10122302
# 2                                      NaN               David Lee  0010Y00001D1OCN                                  Yonsei University     NaN  NaN       NaN       Virtual     0                  Event  ...               David Lee  2019-04-26T00:00          NaN  A&G-APAC-KOREA-TAIWAN-CORE                   NaN  2019-04-29T00:00  2019-04-26T01:00  2019-04-26T02:00    ECR-137560    ECR-137560
# 3                          DL_BF 19_Yonsei               David Lee  0010Y00001D1OCN                                  Yonsei University     NaN  NaN       NaN  Face to Face     0                  Event  ...               David Lee  2019-04-17T00:00          NaN  A&G-APAC-KOREA-TAIWAN-CORE                   NaN  2019-04-22T00:00  2019-04-17T06:00  2019-04-17T07:00    ECR-137560    ECR-137560
# 4                                      NaN               Grace Kim  0013z00002LttHV                               Daejeon Sun Hospital     NaN  NaN       NaN  Face to Face     0                  Event  ...               Grace Kim  2019-09-26T00:00          NaN               RM-HS-APAC-KR                   NaN  2019-09-29T00:00  2019-09-26T02:30  2019-09-26T06:00  ECR-10325865  ECR-10325865
# ...                                    ...                     ...              ...                                                ...     ...  ...       ...           ...   ...                    ...  ...                     ...               ...          ...                         ...                   ...               ...               ...               ...           ...           ...
# 317789                                 NaN  [Inactive] Landon Bell              NaN                                                NaN     NaN  NaN  3-Medium           NaN     1                   Task  ...  [Inactive] Landon Bell  2019-02-08T00:00          NaN                    Inactive                   NaN  2019-02-08T00:00  2019-02-08T00:00  2019-02-08T00:00           NaN           NaN
# 317790                                 NaN  [Inactive] Landon Bell              NaN                                                NaN     NaN  NaN  3-Medium           NaN     1                   Task  ...  [Inactive] Landon Bell  2019-01-08T00:00          NaN                    Inactive                   NaN  2019-01-08T00:00  2019-01-08T00:00  2019-01-08T00:00           NaN           NaN
# 317791                                 NaN  [Inactive] Landon Bell              NaN                                                NaN     NaN  NaN  3-Medium           NaN     1                   Task  ...  [Inactive] Landon Bell  2019-01-10T00:00          NaN                    Inactive                   NaN  2019-01-10T00:00  2019-01-10T00:00  2019-01-10T00:00           NaN           NaN
# 317792                                 NaN  [Inactive] Landon Bell              NaN                                                NaN     NaN  NaN  3-Medium           NaN     1                   Task  ...  [Inactive] Landon Bell  2019-01-29T00:00          NaN                    Inactive                   NaN  2019-01-29T00:00  2019-01-29T00:00  2019-01-29T00:00           NaN           NaN
# 317793                                 NaN  [Inactive] Landon Bell              NaN                                                NaN     NaN  NaN  3-Medium           NaN     1                   Task  ...  [Inactive] Landon Bell  2019-05-01T00:00          NaN                    Inactive                   NaN  2019-05-01T00:00  2019-05-01T00:00  2019-05-01T00:00           NaN           NaN
#
# [317794 rows x 31 columns]

# %%
for i in range(0,df.shape[1]):
    print(df.iloc[:,i].value_counts())
# Out:
# DC                                                              814
# DS Digital Commons - Expert Gallery Suite                       422
# DC - EGS                                                        313
# 2019 | Scopus Custom Data (REQUIRES NEW CONTRACT) | NSF | JM    271
# eBooks 2019                                                     214
#                                                                ...
# 2016 Pure NJ Portal Rutgers                                       1
# PRint conversion journals                                         1
# NLM MidYear Additions                                             1
# Rensselaer Polytechnic Institute- Scopus 2019                     1
# AseA Cambridge International                                      1
# Name: Opportunity, Length: 34295, dtype: int64
# Jessemay Diah Tuyay          6854
# Sadmin Sadmin                6771
# B2BMA Integration            6732
# Andrew Heldt                 6671
# Jamie Bridewell              6373
#                              ...
# [Inactive] Jennifer Tesch       1
# Tara Pierce                     1
# Akshaya Suresh                  1
# Paulina Tseneva                 1
# Samuel Deva Sudhan              1
# Name: Created By, Length: 1026, dtype: int64
# 0010Y00001FvEI8    338
# 0010Y00001FulPE    332
# 0010Y00001C3sIk    285
# 0010Y00001Fv190    263
# 0010Y00001FuzMG    243
#                   ...
# 0010Y00001FvhBn      1
# 0010Y00001H0SNe      1
# 0010Y00001FunSM      1
# 0010Y00001FudOk      1
# 0010Y00001D19dS      1
# Name: Account ID, Length: 25947, dtype: int64
# Elsevier                                                  716
# National Science Foundation                               351
# National Autonomous University of Mexico                  333
# EA Test Company01                                         285
# Exponent Inc                                              282
#                                                          ...
# Elsevier Clinical Solutions                                 1
# king saud bin abdulaziz university for health sciences      1
# Kingston Health Sciences Centre                             1
# Hellenic Petroleum SA                                       1
# Hibbing Community College                                   1
# Name: Company / Account, Length: 41104, dtype: int64
# Cher Lien                   295
# Frank Feng                  213
# CSSales Ops CIM             158
# Saloumeh Kolahchyan         132
# Jennifer Brannum            123
#                            ...
# Kim Zwillo                    1
# Shiho Tachibana               1
# Dave Anderson                 1
# Artur Vasilyevich Belkov      1
# Cindy Craig                   1
# Name: Contact, Length: 42264, dtype: int64
# Andrew Kaczorowski                   315
# Diogo Caldeira Pires                 304
# Test Test                            226
# Focco Test                            56
# Identify Update Contact               28
#                                     ...
# Michael Ejiodu                         1
# Rafael Pacheco                         1
# Giovanny Alejandro Cuervo Londoño      1
# Sonilal Chakrapani                     1
# Dr Anita Setarehnejad                  1
# Name: Lead, Length: 22487, dtype: int64
# 3-Medium    194975
# Low           6641
# 1-ASAP        5174
# 4-Low         2580
# 2-High        2437
# Name: Priority, dtype: int64
# Virtual         51791
# Face to Face    47874
# Phone           19294
# Other            9475
# Online           6243
# Email             953
# Name: Activity Type, dtype: int64
# 1    211807
# 0    105987
# Name: Task, dtype: int64
# Task          210950
# Event         105987
# Mitigation       857
# Name: Task/Event Record Type, dtype: int64
# Email    143303
# Task      44209
# Call      24295
# Name: Task Subtype, dtype: int64
# Event    105987
# Name: Event Subtype, dtype: int64
# Meeting                                                                                       29275
# Call                                                                                          28371
# Email                                                                                          6959
# Email: Thank you for your interest in SCOPUS                                                   5384
# CS - Misc.                                                                                     4066
#                                                                                               ...
# GA - schedule 2019 training session                                                               1
# Email: Case 00069496                                                                              1
# Unresolved Email: Recall: Request for Lump Payment Qualifications for Active CPpbCK client        1
# Bepress Note: Oracle Invoice - 2100034099                                                         1
# PE Healthcheck                                                                                    1
# Name: Subject, Length: 97921, dtype: int64
# ALA forum invite                          5
# left VM                                   3
# talked to asst to the provost             2
# em to request call appt to discuss OER    1
# 427                                       1
#                                          ..
# MAY886                                    1
# 358                                       1
# MAY655                                    1
# 349                                       1
# MAY530                                    1
# Name: Call Result, Length: 1697, dtype: int64
# Other                                                                                                          2487
# Product feedback and features                                                                                  2349
# Value Proposition                                                                                              2020
# Product feedback and features; Value Proposition                                                               1223
# Institutional insight                                                                                          1161
#                                                                                                                ...
# Competition; Market trends; Pricing discussion; Other                                                             1
# Product feedback and features; Value Proposition; Competition; Market trends; Pricing discussion                  1
# Value Proposition; Competition; Institutional insight; Market trends; Other                                       1
# Product feedback and features; Competition; Institutional insight; Market trends; Pricing discussion; Other       1
# Competition; Market trends; Pricing discussion                                                                    1
# Name: Topics Discussed, Length: 121, dtype: int64
# Create a new deal handover form for the linked Opportunity.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1665
# #XL_EVAL_ERROR#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1308
# Left a voicemail.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                907
# LVM                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              544
# Routed to voicemail.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             309
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# Spoke with Ronke at the ELD Dinner. She had no issues to report and was happy overall with the services being provided by Elsevier. She is always happy to see her Reps and pleased to have us visit the campus.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# This was prospecting call and preconditioning call with customer IP team & Information management in charge.\r\nCustomer is interested in getting detailed information on our various solution to decide whether thare is any needs which can be addressed with these solution however I requested them to have first discussion on various current challenges of the R&D function and future vision of their organization accordingly we will share the right solution post our discussion. Customer agrees to meet in the next week to have primary need analysis discussion.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# Need to have Embae training at Yangsan Campus and Ami Campus.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# To: ResearchNetworksMEO@elsevier.com\r\nCC: \r\nBCC: \r\nAttachment: --none--\r\n\r\nSubject: Re: Thank you for your interest in  ScienceDirect\r\nBody:\r\n*** External email: use caution *** I have now reached out twice and have yet to be contacted by a sales consultant.  Please have someone reach out to me immediately.\r\nThank you.\r\nAli\r\n\r\nAli M Chappell PhD, MS\r\n\r\nAssociate Medical Director\r\n\r\nCooperSurgical | Medical Devices \r\n\r\n75 Corporate Drive | Trumbull, CT 06611\r\n\r\nP +1 203-601-5200 | +1 800-645-3760\r\nwww.coopersurgical.com\r\n\r\nThis email and any attachments are intended to be disclosed only to the addressee named herein and may contain information which is confidential. If you are not the named addressee, you are hereby notified that your receipt of the email was unintentional and\r\n that any disclosure, copying or distribution of the email and attachments thereto is strictly prohibited. Please immediately and permanently delete the email and any copies thereof.\r\n\r\nFrom: Elsevier <researchnetworksmeo@elsevier.com>\r\nSent: Thursday, January 3, 2019 3:18:33 AM\r\nTo: Ali Chappell\r\nSubject: Thank you for your interest in ScienceDirect  Dear  Ali Chappell,\r\n \r\nThank you for your recent interest in ScienceDirect.\r\n \r\nWe would like to inform you that we have forwarded your inquiry to our Sales consultants, and an account representative from your region will be in contact with you soon to discuss your\r\n specific needs and what we can offer you. If you have any further questions, please do not hesitate to contact us.\r\n \r\nKind Regards,\r\nResearch Networks Marketing Operations\r\nResearchNetworksMEO@elsevier.com\r\n Marketing cannot provide any pricing details.\r\n______________________________________________________________________\r\n\r\nThis email has been scanned by the Symantec Email Security.cloud service.\r\n\r\nFor more information please visit http://www.symanteccloud.com\r\n\r\n______________________________________________________________________       1
# To: oyediranoluwadara@gmail.com\r\nCC: \r\nBCC: researchnetworksmeo@elsevier.com\r\nAttachment: --none--\r\n\r\nSubject: Thank you for your interest in eBooks\r\nBody:\r\nDear Oyediran Oluwadara,\r\n \r\nThank you for your interest in eBooks. At this time, access to eBooks. is only available via subscriptions purchased by institutions, companies and other organizations for their users. \r\n\r\nIf you are an individual or student user, you have the following options:\r\n\r\n\tCheck with the appropriate representative from your organization or institution if you have access and how to access it from the institutional premises.\r\n\tSpeak to the appropriate representative from your organization or institution about your interest\r\n\tVisit the Elsevier Website and shop for eBooks, Journals and More https://www.elsevier.com/books-and-journals \r\n\r\nKind Regards,\r\nResearch Networks Marketing Operations\r\nResearchNetworksMEO@elsevier.com                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# Name: Comments, Length: 130101, dtype: int64
# Create a new deal handover form for the linked Opportunity.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1665
# #XL_EVAL_ERROR#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1308
# Left a voicemail.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                907
# LVM                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              544
# Routed to voicemail.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             309
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# Spoke with Ronke at the ELD Dinner. She had no issues to report and was happy overall with the services being provided by Elsevier. She is always happy to see her Reps and pleased to have us visit the campus.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# This was prospecting call and preconditioning call with customer IP team & Information management in charge.\r\nCustomer is interested in getting detailed information on our various solution to decide whether thare is any needs which can be addressed with these solution however I requested them to have first discussion on various current challenges of the R&D function and future vision of their organization accordingly we will share the right solution post our discussion. Customer agrees to meet in the next week to have primary need analysis discussion.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# Need to have Embae training at Yangsan Campus and Ami Campus.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# To: ResearchNetworksMEO@elsevier.com\r\nCC: \r\nBCC: \r\nAttachment: --none--\r\n\r\nSubject: Re: Thank you for your interest in  ScienceDirect\r\nBody:\r\n*** External email: use caution *** I have now reached out twice and have yet to be contacted by a sales consultant.  Please have someone reach out to me immediately.\r\nThank you.\r\nAli\r\n\r\nAli M Chappell PhD, MS\r\n\r\nAssociate Medical Director\r\n\r\nCooperSurgical | Medical Devices \r\n\r\n75 Corporate Drive | Trumbull, CT 06611\r\n\r\nP +1 203-601-5200 | +1 800-645-3760\r\nwww.coopersurgical.com\r\n\r\nThis email and any attachments are intended to be disclosed only to the addressee named herein and may contain information which is confidential. If you are not the named addressee, you are hereby notified that your receipt of the email was unintentional and\r\n that any disclosure, copying or distribution of the email and attachments thereto is strictly prohibited. Please immediately and permanently delete the email and any copies thereof.\r\n\r\nFrom: Elsevier <researchnetworksmeo@elsevier.com>\r\nSent: Thursday, January 3, 2019 3:18:33 AM\r\nTo: Ali Chappell\r\nSubject: Thank you for your interest in ScienceDirect  Dear  Ali Chappell,\r\n \r\nThank you for your recent interest in ScienceDirect.\r\n \r\nWe would like to inform you that we have forwarded your inquiry to our Sales consultants, and an account representative from your region will be in contact with you soon to discuss your\r\n specific needs and what we can offer you. If you have any further questions, please do not hesitate to contact us.\r\n \r\nKind Regards,\r\nResearch Networks Marketing Operations\r\nResearchNetworksMEO@elsevier.com\r\n Marketing cannot provide any pricing details.\r\n______________________________________________________________________\r\n\r\nThis email has been scanned by the Symantec Email Security.cloud service.\r\n\r\nFor more information please visit http://www.symanteccloud.com\r\n\r\n______________________________________________________________________       1
# To: oyediranoluwadara@gmail.com\r\nCC: \r\nBCC: researchnetworksmeo@elsevier.com\r\nAttachment: --none--\r\n\r\nSubject: Thank you for your interest in eBooks\r\nBody:\r\nDear Oyediran Oluwadara,\r\n \r\nThank you for your interest in eBooks. At this time, access to eBooks. is only available via subscriptions purchased by institutions, companies and other organizations for their users. \r\n\r\nIf you are an individual or student user, you have the following options:\r\n\r\n\tCheck with the appropriate representative from your organization or institution if you have access and how to access it from the institutional premises.\r\n\tSpeak to the appropriate representative from your organization or institution about your interest\r\n\tVisit the Elsevier Website and shop for eBooks, Journals and More https://www.elsevier.com/books-and-journals \r\n\r\nKind Regards,\r\nResearch Networks Marketing Operations\r\nResearchNetworksMEO@elsevier.com                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# Name: Full Comments, Length: 130101, dtype: int64
# done                                                                  11
# Call                                                                   4
# Follow-up renewal                                                      4
# EGS                                                                    4
# Follow-up Quote                                                        4
#                                                                       ..
# customer agreement signature                                           1
# IR at ICUF                                                             1
# How PURE can help enhance USM visibility on an International stage     1
# F-up complete                                                          1
# Negotiation on the Renewal rate                                        1
# Name: Follow Up Subject, Length: 472, dtype: int64
# Organize, with Miguel, a visit at this customer, to evaluate UTD national deal impact and possibility of CK subscription                               2
# Call                                                                                                                                                   2
# done                                                                                                                                                   2
# eBook sales done and closed                                                                                                                            2
# Follow up in August wrt to planing for training H2.                                                                                                    1
#                                                                                                                                                       ..
# Lusodoc will schedule a follow-up meeting with Dr. Rui Enriques for trial evaluation                                                                   1
# Signed agreement to be uploaded in SFDC                                                                                                                1
# send update highlighting the improved scopus reaxys interlinking                                                                                       1
# - Talk with usage dept: no more supported\r\n-NEXT STEP: discussion W/ Elena and Sonja, to know if in future this could be supported again on 09/10    1
# Spoke with Scott and George and we have a plan                                                                                                         1
# Name: Follow Up Notes, Length: 178, dtype: int64
# SciVal                             77
# Scopus                             13
# content coverage and quality       13
# Franklin Covey                     12
# content quality and coverage       12
#                                    ..
# Ownership vs rental acquisition     1
# good use                            1
# SciVal & Scopus                     1
# XML superior data model             1
# Pathway Studio Enterprise           1
# Name: Name of Value Prop, Length: 477, dtype: int64
# 00U3z00000rYeau    1
# 00T1v00001WgIdp    1
# 00T3z00005ioTIV    1
# 00T3z00005f19q4    1
# 00T3z00005jSUu8    1
#                   ..
# 00U1v00000NBvmz    1
# 00T0Y000016XxoM    1
# 00T1v00001rT8Mi    1
# 00T0Y000016YFN4    1
# 00T1v00001wWvj2    1
# Name: Activity ID, Length: 317794, dtype: int64
# Jessemay Diah Tuyay             6865
# Andrew Heldt                    6702
# B2BMA Integration               6641
# Rachelle Arenas                 6398
# Jamie Bridewell                 6389
#                                 ...
# [Inactive] Stephanie Marquez       1
# Anton Jumelet                      1
# Brenda Goi                         1
# Sreeneth Juttu                     1
# Mark Siebert                       1
# Name: Assigned, Length: 1214, dtype: int64
# 2019-10-15T00:00    2972
# 2019-10-21T00:00    2757
# 2019-10-28T00:00    2624
# 2019-09-05T00:00    2099
# 2019-06-10T00:00    1760
#                     ...
# 2022-07-21T00:00       1
# 2023-07-20T00:00       1
# 2022-05-05T00:00       1
# 2018-10-07T00:00       1
# 2024-07-13T00:00       1
# Name: Date, Length: 1720, dtype: int64
# Knovel Technical Reference                           1
# Embase                                               1
# AACN- Essentials of Critical Care Orientation 3.7    1
# Digital Commons - Recurring                          1
# Name: Product Name, dtype: int64
# A&G-NOAM-INSIDE-2                             42471
# Marketing Reporting                           31999
# Inactive                                      11333
# CRM Support & Training                         9153
# PS-LS-MAEU                                     8911
#                                               ...
# Director PS Marketing - CS Americas (Reid)        1
# CMD-A&G-MAEU                                      1
# Account Support Manager - EMEA 4                  1
# Director, LS Project Management                   1
# Science-Metrix                                    1
# Name: Assigned Role, Length: 316, dtype: int64
# AM - CS Americas 17                          982
# EBSCO Partner User                           126
# Kinokuniya Co Ltd Partner User                78
# RM - CS Americas 9                            18
# Accucoms BV Partner User                      12
# Voicentric Limited Partner User               10
# Credit Controller                              7
# Maruzen International Co Ltd Partner User      6
# Name: Assigned Role Display, dtype: int64
# 2018-07-21T00:00    9307
# 2019-10-15T00:00    2909
# 2019-10-21T00:00    2896
# 2019-10-28T00:00    2682
# 2019-05-07T00:00    2124
#                     ...
# 2010-01-29T00:00       1
# 2011-06-24T00:00       1
# 2012-12-04T00:00       1
# 2018-05-19T00:00       1
# 2010-02-26T00:00       1
# Name: Created Date, Length: 669, dtype: int64
# 2019-10-15T00:00    2481
# 2019-10-21T00:00    2305
# 2019-10-28T00:00    2271
# 2019-09-05T00:00    1588
# 2019-06-10T00:00    1402
#                     ...
# 2019-06-25T12:20       1
# 2019-08-20T21:15       1
# 2018-12-23T10:00       1
# 2019-07-16T06:30       1
# 2021-02-12T05:00       1
# Name: Start, Length: 18378, dtype: int64
# 2019-10-15T00:00    2480
# 2019-10-21T00:00    2302
# 2019-10-28T00:00    2261
# 2019-09-05T00:00    1588
# 2019-06-10T00:00    1400
#                     ...
# 2019-10-27T14:30       1
# 2019-09-27T13:35       1
# 2019-08-04T04:00       1
# 2019-09-25T01:00       1
# 2019-11-29T09:50       1
# Name: End, Length: 20294, dtype: int64
# ECR-56966       338
# ECR-1828        332
# ECR-28866491    285
# ECR-433882      263
# ECR-1038939     243
#                ...
# ECR-10353444      1
# ECR-33091166      1
# ECR-1144274       1
# ECR-31047545      1
# ECR-33934176      1
# Name: ECR Id, Length: 25902, dtype: int64
# ECR-611         854
# ECR-1134        500
# ECR-59345       408
# ECR-750         404
# ECR-1102        402
#                ...
# ECR-712986        1
# ECR-1116574       1
# ECR-31345885      1
# ECR-469580        1
# ECR-842362        1
# Name: Parent ECR-ID, Length: 23166, dtype: int64

# %% [markdown]
# ### Summary of the dataframe

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(get_data_frame_summmary(df))
# Out:
#                      index                                      unique_values  unique_counts data_type  percent_missing
# 23            Product Name  [[nan, Digital Commons - Recurring, Knovel Tec...              5    object           100.00
# 18         Follow Up Notes  [[nan, No answer in July, try in September, Ma...            179    object            99.94
# 17       Follow Up Subject  [[nan, Chase for feedback, Check project statu...            473    object            99.84
# 19      Name of Value Prop  [[nan, DVCRI Value Story, Clinical practice, C...            478    object            99.76
# 25   Assigned Role Display  [[nan, AM - CS Americas 17, Credit Controller,...              9    object            99.61
# 13             Call Result  [[nan, 260, called the main library number; Ja...           1698    object            99.46
# 14        Topics Discussed  [[nan, Product feedback and features; Institut...            122    object            95.40
# 5                     Lead  [[nan, Gerald Crown, Christine Elliott, Kelley...          22488    object            86.08
# 11           Event Subtype                                     [[Event, nan]]              2    object            66.65
# 0              Opportunity  [[nan, SY_ELS_CK_2020_Mito Medical Center, DL_...          34296    object            58.08
# 7            Activity Type  [[Face to Face, nan, Virtual, Online, Phone, E...              7    object            57.32
# 4                  Contact  [[nan, ZZZZZZ_Wendalyn Russ-Cook_ZZZZZZ, Zweie...          42265    object            52.29
# 16           Full Comments  [[nan, I provided EMBASE for last 15 months., ...         130102    object            52.04
# 15                Comments  [[nan, I provided EMBASE for last 15 months., ...         130102    object            52.04
# 10            Task Subtype                         [[nan, Task, Email, Call]]              4    object            33.35
# 6                 Priority      [[nan, 1-ASAP, 3-Medium, 2-High, Low, 4-Low]]              6    object            33.35
# 29                  ECR Id  [[ECR-593174, ECR-202329, ECR-137560, ECR-1032...          25903    object            20.11
# 30           Parent ECR-ID  [[ECR-593174, ECR-10122302, ECR-137560, ECR-10...          23167    object            20.11
# 2               Account ID  [[0010Y00001FvC5o, 0010Y00001FwK3c, 0010Y00001...          25948    object            20.02
# 3        Company / Account  [[National Hospital Organization Hokkaido Medi...          41105    object             6.16
# 12                 Subject  [[Meeting, Email - EMBASE Usage, Meeting - BF ...          97922    object             3.81
# 24           Assigned Role  [[HS-APAC-JP_N, HS-APAC-JP_C, A&G-APAC-KOREA-T...            317    object             2.16
# 27                   Start  [[2019-07-04T02:00, 2019-11-15T03:00, 2019-04-...          18379    object             0.63
# 28                     End  [[2019-07-04T02:30, 2019-11-15T04:00, 2019-04-...          20295    object             0.63
# 22                    Date  [[2019-07-04T00:00, 2019-11-15T00:00, 2019-04-...           1721    object             0.63
# 21                Assigned  [[Chinami Takebe, Shiho Yakabe, David Lee, Gra...           1215    object             0.20
# 1               Created By  [[Chinami Takebe, Shiho Yakabe, David Lee, Gra...           1027    object             0.19
# 20             Activity ID  [[00U1v00000SNwK8, 00U3z00000rZouU, 00U1v00000...         317794    object             0.00
# 8                     Task                                           [[0, 1]]              2     int64             0.00
# 26            Created Date  [[2019-07-04T00:00, 2019-12-04T00:00, 2019-04-...            669    object             0.00
# 9   Task/Event Record Type                        [[Event, Task, Mitigation]]              3    object             0.00

# %% [markdown]
# # Identify Missing Data
#
# Missing values affect the performance of the machine learning models and its useful to identify and drop or impute missing values before modelling.
#
# We will quantify the missing data and drop any columns lower than the given threshold. we have set threshold of 70% so any columns and rows with missing data over 70% are dropped.
#
# In this case, we will also manually drop Event Subtype, Opportunity, Contact, Full Comments, Comments and Company / Account.

# %%
#set threshold
threshold = 0.7


#Dropping columns with missing value rate higher than threshold
temp = df[df.columns[df.isnull().mean() < threshold]]

print('-------------------- Dropping Columns with missing data --------------------')
print(f'Following {len(df.columns.difference(temp.columns))} columns have missing data over the threshold and will be removed')
print(df.columns.difference(temp.columns))

df = temp

print('-------------------- Dropping rows with missing data --------------------')
print(f' There are {sum(df.isnull().mean(axis=1) > threshold)} rows with missing data over the threshold')

#Dropping rows with missing value rate higher than threshold
df = df.loc[df.isnull().mean(axis=1) < threshold]

# remove temp object from memory
del temp

#manually remove other columns
df = df.drop(columns=['Event Subtype', 'Opportunity', 'Contact', 'Full Comments', 'Comments', 'Company / Account'])
# Out:
# -------------------- Dropping Columns with missing data --------------------
# Following 8 columns have missing data over the threshold and will be removed
# Index(['Assigned Role Display', 'Call Result', 'Follow Up Notes',
#        'Follow Up Subject', 'Lead', 'Name of Value Prop', 'Product Name',
#        'Topics Discussed'],
#       dtype='object')
# -------------------- Dropping rows with missing data --------------------
#  There are 0 rows with missing data over the threshold

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(get_data_frame_summmary(df))
# Out:
#                      index                                      unique_values  unique_counts data_type  percent_missing
# 3            Activity Type  [[Face to Face, nan, Virtual, Online, Phone, E...              7    object            57.32
# 2                 Priority      [[nan, 1-ASAP, 3-Medium, 2-High, Low, 4-Low]]              6    object            33.35
# 6             Task Subtype                         [[nan, Task, Email, Call]]              4    object            33.35
# 15                  ECR Id  [[ECR-593174, ECR-202329, ECR-137560, ECR-1032...          25903    object            20.11
# 16           Parent ECR-ID  [[ECR-593174, ECR-10122302, ECR-137560, ECR-10...          23167    object            20.11
# 1               Account ID  [[0010Y00001FvC5o, 0010Y00001FwK3c, 0010Y00001...          25948    object            20.02
# 7                  Subject  [[Meeting, Email - EMBASE Usage, Meeting - BF ...          97922    object             3.81
# 11           Assigned Role  [[HS-APAC-JP_N, HS-APAC-JP_C, A&G-APAC-KOREA-T...            317    object             2.16
# 13                   Start  [[2019-07-04T02:00, 2019-11-15T03:00, 2019-04-...          18379    object             0.63
# 14                     End  [[2019-07-04T02:30, 2019-11-15T04:00, 2019-04-...          20295    object             0.63
# 10                    Date  [[2019-07-04T00:00, 2019-11-15T00:00, 2019-04-...           1721    object             0.63
# 9                 Assigned  [[Chinami Takebe, Shiho Yakabe, David Lee, Gra...           1215    object             0.20
# 0               Created By  [[Chinami Takebe, Shiho Yakabe, David Lee, Gra...           1027    object             0.19
# 12            Created Date  [[2019-07-04T00:00, 2019-12-04T00:00, 2019-04-...            669    object             0.00
# 5   Task/Event Record Type                        [[Event, Task, Mitigation]]              3    object             0.00
# 4                     Task                                           [[0, 1]]              2     int64             0.00
# 8              Activity ID  [[00U1v00000SNwK8, 00U3z00000rZouU, 00U1v00000...         317794    object             0.00

# %% [markdown]
# ### Data Imputation
#
# We can impute missing data with meaningful data so that model development has good quality of data
#
# We can impute categorical variables with the most frequestly occuring value and impute numerical variables with 0 or mean or median depending on the variable context.
#
# Activity Type - Impute with most frequent
#
# Priority - Impute with most frequent
#
# Task Subtype - Impute with most frequent

# %%
# #Filling all missing values with 0
# # data = data.fillna(0)

# #Filling missing values with the most frequest values
# df['Activity Type'].fillna(
#     df['Activity Type'].value_counts().idxmax(), inplace=True)

# df['Priority'].fillna(
#     df['Priority'].value_counts().idxmax(), inplace=True)

# df['Task Subtype'].fillna(
#     df['Task Subtype'].value_counts().idxmax(), inplace=True)

# %% [markdown]
# # Handling Outliers
#
# Extreme value can skew the data distribution and thus affect the model development we identify outliers in numeric variables and handle them by removing or capping.
#
# ### Outlier Detection with Percentiles

# %%
#Dropping the outlier rows with Percentiles

df = drop_outliers(df, exclude = ['Task'])

# %% [markdown]
# # Binning
#
# The main motivation of binning is to make the model more robust and prevent overfitting, however, it has a cost to the performance. Every time you bin something, you sacrifice information and make your data more regularized
#
# The trade-off between performance and overfitting is the key point of the binning process
#
#
# For Categorical variables the labels with low frequencies probably affect the robustness of statistical models negatively. Thus, assigning a general category to these less frequent values helps to keep the robustness of the model.
#
# it is a good option to unite the labels with a count less than 100 to a new category like “Other”.

# %%
binning_summary = get_data_frame_summmary(df, 
                                    sort_by='unique_counts', 
                                    ascending=True)

# %% [markdown]
# ### Columns with less than 100 unique categories

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(binning_summary[binning_summary['unique_counts'] < 100])
# Out:
#                     index                                      unique_values  unique_counts data_type  percent_missing
# 4                    Task                                           [[0, 1]]              2     int64             0.00
# 5  Task/Event Record Type                        [[Event, Task, Mitigation]]              3    object             0.00
# 6            Task Subtype                         [[nan, Task, Email, Call]]              4    object            33.35
# 2                Priority      [[nan, 1-ASAP, 3-Medium, 2-High, Low, 4-Low]]              6    object            33.35
# 3           Activity Type  [[Face to Face, nan, Virtual, Online, Phone, E...              7    object            57.32

# %%
columns_to_bin = binning_summary[binning_summary['unique_counts'] < 100]['index'].to_list()

# %%
# select columns with less than 100 labels
df = df.apply(lambda x: x.mask(x.map(x.value_counts())<10, 'Other') if x.name in columns_to_bin else x)

# %% [markdown]
# ### After Binning - Columns with less than 100 unique categories

# %%
binning_summary = get_data_frame_summmary(df, 
                                    sort_by='unique_counts', 
                                    ascending=True)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(binning_summary[binning_summary['unique_counts'] < 100])
# Out:
#                     index                                      unique_values  unique_counts data_type  percent_missing
# 4                    Task                                           [[0, 1]]              2     int64             0.00
# 5  Task/Event Record Type                        [[Event, Task, Mitigation]]              3    object             0.00
# 6            Task Subtype                         [[nan, Task, Email, Call]]              4    object            33.35
# 2                Priority      [[nan, 1-ASAP, 3-Medium, 2-High, Low, 4-Low]]              6    object            33.35
# 3           Activity Type  [[Face to Face, nan, Virtual, Online, Phone, E...              7    object            57.32

# %% [markdown]
# ## Log Transform
#
# Logarithm transformation (or log transform) is one of the most commonly used mathematical transformations
#
# It helps to handle skewed data and after transformation, the distribution becomes more approximate to normal.
# In most of the cases the magnitude order of the data changes within the range of the data. log transform normalizes the magnitude differences.
#
# It also decreases the effect of the outliers, due to the normalization of magnitude differences and the model become more robust.
#
# Important note: The data you apply log transform must have only positive values, otherwise you receive an error. Also, you can add 1 to your data before transform it. Thus, you ensure the output of the transformation to be positive.

# %%
# No Log transform applied

# %% [markdown]
# ## Scaling
#
# In most cases, the numerical features of the dataset do not have a certain range and they differ from each other. Scaling solves this problem. The continuous features become identical in terms of the range, after a scaling process. This process is not mandatory for many algorithms, but it might be still nice to apply.
#
# ### Normalization
#
# Normalization (or min-max normalization) scale all values in a fixed range between 0 and 1. This transformation does not change the distribution of the feature and due to the decreased standard deviations, the effects of the outliers increases. Therefore, before normalization, it is recommended to handle the outliers
#
# ### Standardization
# Standardization (or z-score normalization) scales the values while taking into account standard deviation. If the standard deviation of features is different, their range also would differ from each other. This reduces the effect of the outliers in the features.
# In the following formula of standardization, the mean is shown as μ and the standard deviation is shown as σ.

# %%
df = scale_numeric_features(df, inplace=True)
# Out:
# ********************* - Scaling following 1 features - **********************
#  Task standardized to Task

# %% [markdown]
# ## One-hot encoding
#
# This method spreads the values in a column to multiple flag columns and assigns 0 or 1 to them. These binary values express the relationship between grouped and encoded column.
#
# This method changes your categorical data, which is challenging to understand for algorithms, to a numerical format
#
# If you have N distinct values in the column, it is enough to map them to N-1, as the missing value can be deduced from the other columns

# %%
#print(columns_to_bin)

# %%
# Specify Columns to encode
# columns_to_exclude = []
# columns_to_include = columns_to_bin
# columns_to_encode = remove_items(columns_to_include, columns_to_exclude)
# columns_to_encode

# %%
# for column in columns_to_encode:
#     encoded_columns = pd.get_dummies(df[column])
#     print(f'Encoding collumns : {column} to {len(encoded_columns.columns)} new encoded columns')
#     df = df.join(encoded_columns, rsuffix='_'+column).drop(column, axis=1)

# %%
#df.shape

# %%
df.head()
# Out:
#        Created By       Account ID Priority Activity Type  Task Task/Event Record Type Task Subtype                Subject      Activity ID        Assigned              Date               Assigned Role      Created Date             Start               End        ECR Id Parent ECR-ID
# 0  Chinami Takebe  0010Y00001FvC5o      NaN  Face to Face -1.41                  Event          NaN                Meeting  00U1v00000SNwK8  Chinami Takebe  2019-07-04T00:00                HS-APAC-JP_N  2019-07-04T00:00  2019-07-04T02:00  2019-07-04T02:30    ECR-593174    ECR-593174
# 1    Shiho Yakabe  0010Y00001FwK3c      NaN           NaN -1.41                  Event          NaN                Meeting  00U3z00000rZouU    Shiho Yakabe  2019-11-15T00:00                HS-APAC-JP_C  2019-12-04T00:00  2019-11-15T03:00  2019-11-15T04:00    ECR-202329  ECR-10122302
# 2       David Lee  0010Y00001D1OCN      NaN       Virtual -1.41                  Event          NaN   Email - EMBASE Usage  00U1v00000QZ6eu       David Lee  2019-04-26T00:00  A&G-APAC-KOREA-TAIWAN-CORE  2019-04-29T00:00  2019-04-26T01:00  2019-04-26T02:00    ECR-137560    ECR-137560
# 3       David Lee  0010Y00001D1OCN      NaN  Face to Face -1.41                  Event          NaN  Meeting - BF Proposal  00U1v00000QG3jm       David Lee  2019-04-17T00:00  A&G-APAC-KOREA-TAIWAN-CORE  2019-04-22T00:00  2019-04-17T06:00  2019-04-17T07:00    ECR-137560    ECR-137560
# 4       Grace Kim  0013z00002LttHV      NaN  Face to Face -1.41                  Event          NaN                Meeting  00U3z00000qky6Z       Grace Kim  2019-09-26T00:00               RM-HS-APAC-KR  2019-09-29T00:00  2019-09-26T02:30  2019-09-26T06:00  ECR-10325865  ECR-10325865

# %% [markdown]
# ## Transform Date columns
#
# Recency and Frequency Variables and length / duration.

# %%
# convert date columns to date data type

date_columns = ['Start', 'End', 'Date', 'Created Date']

# %%
for column in date_columns:
    df[column] = pd.to_datetime(df[column])

# %%
# calculate new variable activity_length
df['activity_length'] = months_between_columns(df['End'],df['Start'])

# %%
 df.head()
# Out:
#        Created By       Account ID Priority Activity Type  Task Task/Event Record Type Task Subtype                Subject      Activity ID        Assigned       Date               Assigned Role Created Date               Start                 End        ECR Id Parent ECR-ID  activity_length
# 0  Chinami Takebe  0010Y00001FvC5o      NaN  Face to Face -1.41                  Event          NaN                Meeting  00U1v00000SNwK8  Chinami Takebe 2019-07-04                HS-APAC-JP_N   2019-07-04 2019-07-04 02:00:00 2019-07-04 02:30:00    ECR-593174    ECR-593174             0.00
# 1    Shiho Yakabe  0010Y00001FwK3c      NaN           NaN -1.41                  Event          NaN                Meeting  00U3z00000rZouU    Shiho Yakabe 2019-11-15                HS-APAC-JP_C   2019-12-04 2019-11-15 03:00:00 2019-11-15 04:00:00    ECR-202329  ECR-10122302             0.00
# 2       David Lee  0010Y00001D1OCN      NaN       Virtual -1.41                  Event          NaN   Email - EMBASE Usage  00U1v00000QZ6eu       David Lee 2019-04-26  A&G-APAC-KOREA-TAIWAN-CORE   2019-04-29 2019-04-26 01:00:00 2019-04-26 02:00:00    ECR-137560    ECR-137560             0.00
# 3       David Lee  0010Y00001D1OCN      NaN  Face to Face -1.41                  Event          NaN  Meeting - BF Proposal  00U1v00000QG3jm       David Lee 2019-04-17  A&G-APAC-KOREA-TAIWAN-CORE   2019-04-22 2019-04-17 06:00:00 2019-04-17 07:00:00    ECR-137560    ECR-137560             0.00
# 4       Grace Kim  0013z00002LttHV      NaN  Face to Face -1.41                  Event          NaN                Meeting  00U3z00000qky6Z       Grace Kim 2019-09-26               RM-HS-APAC-KR   2019-09-29 2019-09-26 02:30:00 2019-09-26 06:00:00  ECR-10325865  ECR-10325865             0.00

# %% [markdown]
# ## Remove unused and/or redundant Features
#
# Unused features are those that don’t make sense to pass into our machine learning algorithms. such as ID columns
# Features that wouldn't be available at the time of prediction, Other text descriptions
#
# Redundant features would typically be those that have been replaced by other features that you’ve added during feature engineering

# %%
columns_to_remove = ['Subject','Assigned Role']

# %%
df = df.drop(columns_to_remove, axis=1)

# %%
df.head()
# Out:
#        Created By       Account ID Priority Activity Type  Task Task/Event Record Type Task Subtype      Activity ID        Assigned       Date Created Date               Start                 End        ECR Id Parent ECR-ID  activity_length
# 0  Chinami Takebe  0010Y00001FvC5o      NaN  Face to Face -1.41                  Event          NaN  00U1v00000SNwK8  Chinami Takebe 2019-07-04   2019-07-04 2019-07-04 02:00:00 2019-07-04 02:30:00    ECR-593174    ECR-593174             0.00
# 1    Shiho Yakabe  0010Y00001FwK3c      NaN           NaN -1.41                  Event          NaN  00U3z00000rZouU    Shiho Yakabe 2019-11-15   2019-12-04 2019-11-15 03:00:00 2019-11-15 04:00:00    ECR-202329  ECR-10122302             0.00
# 2       David Lee  0010Y00001D1OCN      NaN       Virtual -1.41                  Event          NaN  00U1v00000QZ6eu       David Lee 2019-04-26   2019-04-29 2019-04-26 01:00:00 2019-04-26 02:00:00    ECR-137560    ECR-137560             0.00
# 3       David Lee  0010Y00001D1OCN      NaN  Face to Face -1.41                  Event          NaN  00U1v00000QG3jm       David Lee 2019-04-17   2019-04-22 2019-04-17 06:00:00 2019-04-17 07:00:00    ECR-137560    ECR-137560             0.00
# 4       Grace Kim  0013z00002LttHV      NaN  Face to Face -1.41                  Event          NaN  00U3z00000qky6Z       Grace Kim 2019-09-26   2019-09-29 2019-09-26 02:30:00 2019-09-26 06:00:00  ECR-10325865  ECR-10325865             0.00

# %% [markdown]
# Save clean pickle files

# %%
df.to_pickle("../"+cfg['clean_pickles_for_graphs_dir']+"/"+cfg['churn_activities_file']+"_for_graphs.pickle")
